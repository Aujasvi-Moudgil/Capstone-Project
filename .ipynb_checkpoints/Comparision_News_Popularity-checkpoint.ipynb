# %%
#Import Libraries 

#Basic Libraries 
import pandas as pd 
import numpy as np

#Plotting Libraries 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

#Text Mining
from wordcloud import WordCloud
from nltk.sentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
import nltk

#Warnings
import warnings

#Topic Modelling
from gensim.models.coherencemodel import CoherenceModel
from gensim.models import LdaMulticore
import gensim


#Metrics
from sklearn.metrics import accuracy_score

#Others
from datetime import datetime

# %%
#Read data file 
df = pd.read_csv('News_Final.csv')

# %%
df.head()
# Out:
#     IDLink                                              Title  \
# 0  99248.0   Obama Lays Wreath at Arlington National Cemetery
# 1  10423.0        A Look at the Health of the Chinese Economy
# 2  18828.0   Nouriel Roubini: Global Economy Not Back to 2008
# 3  27788.0                          Finland GDP Expands In Q4
# 4  27789.0  Tourism, govt spending buoys Thai economy in J...
#
#                                             Headline  \
# 0  Obama Lays Wreath at Arlington National Cemete...
# 1  Tim Haywood, investment director business-unit...
# 2  Nouriel Roubini, NYU professor and chairman at...
# 3  Finland's economy expanded marginally in the t...
# 4  Tourism and public spending continued to boost...
#
#                                      Source    Topic          PublishDate  \
# 0                                 USA TODAY    obama  2002-04-02 00:00:00
# 1                                 Bloomberg  economy  2008-09-20 00:00:00
# 2                                 Bloomberg  economy  2012-01-28 00:00:00
# 3                                  RTT News  economy  2015-03-01 00:06:00
# 4  The Nation - Thailand&#39;s English news  economy  2015-03-01 00:11:00
#
#    SentimentTitle  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0        0.000000          -0.053300        -1          -1        -1
# 1        0.208333          -0.156386        -1          -1        -1
# 2       -0.425210           0.139754        -1          -1        -1
# 3        0.000000           0.026064        -1          -1        -1
# 4        0.000000           0.141084        -1          -1        -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93239 entries, 0 to 93238
# Data columns (total 11 columns):
# IDLink               93239 non-null float64
# Title                93239 non-null object
# Headline             93224 non-null object
# Source               92960 non-null object
# Topic                93239 non-null object
# PublishDate          93239 non-null object
# SentimentTitle       93239 non-null float64
# SentimentHeadline    93239 non-null float64
# Facebook             93239 non-null int64
# GooglePlus           93239 non-null int64
# LinkedIn             93239 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 7.8+ MB

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Finding Null Values

# %%
df.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline              15
# Source               279
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %%
df['Source'].value_counts()
# Out:
# Bloomberg                                               1732
# Reuters                                                 1321
# ABC News                                                1098
# New York Times                                           992
# The Guardian                                             933
# Business Insider                                         884
# Economic Times                                           787
# Forbes                                                   781
# Washington Post                                          774
# CNN                                                      742
# Wall Street Journal                                      730
# WinBeta                                                  707
# CNBC                                                     682
# Huffington Post                                          676
# Breitbart News                                           605
# Reuters via Yahoo! Finance                               551
# The Hill                                                 548
# Financial Times                                          544
# USA TODAY                                                530
# ZDNet                                                    526
# MSPoweruser.com                                          516
# Daily Mail                                               510
# Fox News                                                 505
# AFP via Yahoo! News                                      501
# NPR                                                      481
# BBC News                                                 481
# Washington Times                                         448
# The Hill (blog)                                          442
# Associated Press via Yahoo! News                         437
# Reuters via Yahoo! News                                  409
#                                                         ...
# WBAY                                                       1
# Jackson Hole News & Guide                                  1
# Michronicleonline                                          1
# RU Daily Targum                                            1
# The State (blog)                                           1
# Loudwire                                                   1
# Democracy Now! (blog)                                      1
# Investor Newswire                                          1
# KTUL                                                       1
# Dallas Sun Times                                           1
# The Garden City Telegram                                   1
# Namibia Economist                                          1
# The Swedish Wire                                           1
# Wakey Wakey News                                           1
# Coos Bay World                                             1
# SECcountry.com                                             1
# Westlaw Insider (blog)                                     1
# Huron Daily Tribune                                        1
# OCCRP                                                      1
# Business Insider UK Finance via Yahoo! Finance India       1
# Lonoke News                                                1
# WISC-TV Madison                                            1
# UTV Ireland (blog)                                         1
# KnowTechie (blog)                                          1
# Fortune via Yahoo! Finance                                 1
# MadameNoire                                                1
# The Marshalltown                                           1
# Afrik.com                                                  1
# People's World                                             1
# Executive Mosaic Media (blog)                              1
# Name: Source, Length: 5756, dtype: int64

# %% [markdown]
# #### Drop the rows containing Obama and Economy, as per objective we need only Microsoft and Palestine

# %%
df = df.drop(df[df.Topic == 'obama'].index)

# %%
df = df.drop(df[df.Topic == 'economy'].index)

# %%
df.head()
# Out:
#      IDLink                                              Title  \
# 5   27790.0  Intellitec Solutions to Host 13th Annual Sprin...
# 6   80690.0                                Monday, 29 Feb 2016
# 8   80771.0  Fire claims more than 100-year-old barn in Han...
# 9   27803.0        Microsoft's new Windows 10 ad targets Apple
# 10  27813.0  Microsoft Project Centennial seen with “univer...
#
#                                              Headline             Source  \
# 5   Over 100 attendees expected to see latest vers...              PRWeb
# 6   RAMALLAH, February 25, 2016 (WAFA) - Palestine...                NaN
# 8   A Hancock County man lost a barn early Monday ...  WTHR Indianapolis
# 9   New Delhi, Feb.29 : Technology giant Microsoft...         New Kerala
# 10  Microsoft may have burned off one bridge, but ...          SlashGear
#
#         Topic          PublishDate  SentimentTitle  SentimentHeadline  \
# 5   microsoft  2015-03-01 00:19:00       -0.075378           0.036773
# 6   palestine  2016-02-28 14:03:00        0.000000          -0.005906
# 8   palestine  2015-03-01 01:20:00       -0.173925          -0.050185
# 9   microsoft  2015-03-01 01:32:00       -0.059536          -0.081715
# 10  microsoft  2015-03-01 02:14:00        0.000000           0.002550
#
#     Facebook  GooglePlus  LinkedIn
# 5         -1          -1        -1
# 6          0           0         0
# 8         -1          -1        -1
# 9         -1          -1        -1
# 10        -1          -1        -1

# %%
df.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline               4
# Source               239
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %% [markdown]
# #### Fill the Null values

# %%
df.Source.fillna(df.Source.mode()[0],inplace = True) #Replace the null values of the Source with the mode

# %%
df.isnull().sum()
# Out:
# IDLink               0
# Title                0
# Headline             4
# Source               0
# Topic                0
# PublishDate          0
# SentimentTitle       0
# SentimentHeadline    0
# Facebook             0
# GooglePlus           0
# LinkedIn             0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30697 entries, 5 to 93238
# Data columns (total 11 columns):
# IDLink               30697 non-null float64
# Title                30697 non-null object
# Headline             30697 non-null object
# Source               30697 non-null object
# Topic                30697 non-null object
# PublishDate          30697 non-null object
# SentimentTitle       30697 non-null float64
# SentimentHeadline    30697 non-null float64
# Facebook             30697 non-null int64
# GooglePlus           30697 non-null int64
# LinkedIn             30697 non-null int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.8+ MB

# %%
df.describe().T
# Out:
#                      count          mean           std         min  \
# IDLink             30697.0  45491.104831  28776.234078  101.000000
# SentimentTitle     30697.0     -0.004101      0.124857   -0.950694
# SentimentHeadline  30697.0     -0.023314      0.136817   -0.732337
# Facebook           30697.0     36.072906    307.763498   -1.000000
# GooglePlus         30697.0      3.714728     20.283135   -1.000000
# LinkedIn           30697.0     24.653810    246.613707   -1.000000
#
#                             25%           50%           75%            max
# IDLink             20623.000000  44461.000000  66310.000000  104800.000000
# SentimentTitle        -0.068041      0.000000      0.061688       0.714610
# SentimentHeadline     -0.108333     -0.024116      0.060697       0.964646
# Facebook               0.000000      2.000000     14.000000   22346.000000
# GooglePlus             0.000000      0.000000      2.000000    1016.000000
# LinkedIn               0.000000      0.000000      5.000000   20341.000000

# %% [markdown]
# #### Count the items related to different topics

# %%
df['Topic'].value_counts()
# Out:
# microsoft    21857
# palestine     8840
# Name: Topic, dtype: int64

# %%
max_sen_title = df.groupby(['Title','SentimentTitle'], as_index=False).max()

# %%
max_sen_title
# Out:
#                                                    Title  SentimentTitle  \
# 0      !8-year-old Palestine woman killed in wreck on...       -0.014657
# 1      !8-year-old Palestine woman killed in wreck on...       -0.033501
# 2                                         #14. Palestine        0.000000
# 3                                          #4. Palestine        0.000000
# 4      #GivingTuesday Founder 92Y and Founding Partne...       -0.047246
# 5      #GivingTuesday Founder 92Y and Founding Partne...       -0.064550
# 6      #Microsoft Corporation's Senior Director of Gl...       -0.028646
# 7       #Nakba Marked on Twitter on its 68th Anniversary        0.088388
# 8      #PulseList 2015: Microsoft Bing's top searches...        0.000000
# 9      #Sphere 3D's (NASDAQ: $ANY) Collaboration with...        0.000000
# 10                         #dnaEdit: India for Palestine        0.000000
# 11                                    #microsoft landing        0.000000
# 12     #shareyourwarmth campaign launched to assist P...        0.070868
# 13     $159 million in aid to Palestinian Authority b...        0.000000
# 14     $175 will get you the Microsoft Band 2 from th...       -0.025377
# 15     $2.8M Microsoft contract for WV schools sparks...       -0.166667
# 16     $3,000 Microsoft HoloLens dev kit opens for pr...       -0.039528
# 17     $571 million funding appeal launched to addres...        0.000000
# 18                          $58.00 donated in past month        0.000000
# 19     $8,000 Xbox Bill From FIFA Purchases Refunded ...       -0.176777
# 20     $8000 Xbox Bill From FIFA Purchases Refunded b...       -0.176777
# 21     &quot; ARRIVE EN PALESTINE DE LA MISSION SIO...        0.000000
# 22     &quot;Absolutely Not&quot; True That Microsoft...        0.007016
# 23     &quot;Day of Anger&quot; on next Friday in Occ...        0.075378
# 24     &quot;Discriminatory&quot; bank shuts Palestin...        0.132583
# 25             &quot;Economic peace&quot; for Palestine?        0.000000
# 26     &quot;Hack Productivity&quot; with Office 365 ...       -0.046409
# 27     &quot;La Palestine deviendrait un autre Etat a...        0.000000
# 28     &quot;Not True&quot; That Microsoft Will Turn ...       -0.062757
# 29     &quot;Reel 'Em In&quot; Foundation: Brian Robi...       -0.028296
# ...                                                  ...             ...
# 26635  Teachers Could Change The World, Says Pa...        0.018046
# 26636  The international community must work to en...       -0.014757
# 26637  Trans-Tasman first as Softsource seals Micr...        0.072917
# 26638  UAE, Palestine in deal to boost farming rel...        0.088388
# 26639  VMware, Cisco and Microsoft go-to vendors a...       -0.039528
# 26640  Vodafone NZ partners with Microsoft OneDriv...        0.000000
# 26641                  What is Israel supposed to do?        0.000000
# 26642  Why Microsoft vs. US Govt is a huge deal fo...       -0.234097
# 26643   Why Microsoft's Xamarin purchase is a blunder       -0.283473
# 26644  Windows 10 mix hits enterprise as Hewlett P...        0.220971
# 26645  Windows becomes premium OS as Microsoft and...        0.171027
# 26646       Witnessing Palestine with Eve Spangler        0.000000
# 26647  Xero partners with Microsoft to enable big ...        0.164931
# 26648   Your Town Friday returns to New Palestine!       -0.055120
# 26649  ‘Baird you are not welcome in Palestine’: Prot...       -0.257694
# 26650  ‘City of Secret’: a labyrinthine plot in post-...        0.000000
# 26651  ‘Don’t waste World Cup qualifying chance,’ UAE...        0.175898
# 26652  ‘Having lived in Dublin all my life, I’m not u...       -0.057354
# 26653  ‘How can you build values of resistance withou...       -0.108253
# 26654  ‘I don’t want to help Israelis’: Academic refu...        0.014558
# 26655  ‘It’s Palestine, Not Israel,’ Belgian Hotline ...       -0.273245
# 26656  ‘I’m an Irishman in the West Bank helping kids...        0.139643
# 26657          ‘Jew haters’ spread fear at CUNY colleges       -0.047246
# 26658  ‘Order to Kill’: Prominent Rabbi Calls for Poi...       -0.019764
# 26659  ‘Palestine’s Call’ for statehood support sent ...        0.069338
# 26660              ‘The day Israelis rained bombs on us’        0.091866
# 26661  ‘Unrelenting’ Israeli-Palestinian violence lea...        0.028489
# 26662  ‘We do design cloud solutions for hospitals as...        0.052607
# 26663  “Dialogue” isn’t enough to address the Israel-...       -0.095754
# 26664  “We Cannot Go There Now My Dear” Shows Plight ...        0.094222
#
#          IDLink                                           Headline  \
# 0       98543.0  DPS Trooper Jean Dark confirmed that a two-veh...
# 1       98546.0  An 18-year-old Palestine woman was killed in a...
# 2      102518.0  In 2014, Palestine received a total of $497,26...
# 3      100025.0  Palestine. Updated 18 hrs ago; 0 &middot; Pale...
# 4        5733.0  92nd Street Y (92Y), the nonprofit cultural an...
# 5        5709.0  92nd Street Y, the nonprofit cultural and comm...
# 6       59492.0  With over 15 years of corporate security exper...
# 7       98358.0  Palestinians all over the world mark May 15 as...
# 8       11875.0  Just as Facebook and Google have both released...
# 9       15768.0  #Sphere 3D's (NASDAQ: $ANY) Collaboration with...
# 10      73177.0  Sushma Swaraj stated India's support for Pales...
# 11      29233.0  #microsoft landing. # microsoft-landing - Toda...
# 12      66447.0  """Palestine refugees face great uncertainty, ...
# 13      85453.0  Demonstrators take part in a National March on...
# 14      27677.0  Microsoft's fitness tracking wearable, the Mic...
# 15      53014.0  """Softchoice was determined to have been a Mi...
# 16      27938.0   Microsoft is giving HoloLens developers a bet...
# 17      77392.0  Palestinian authorities and the United Nations...
# 18      77738.0  Welcome to this Week in Palestine, a service o...
# 19      19466.0  A father had the credit card bill his son rack...
# 20      19457.0  However, when looking for a refund, Perkins di...
# 21      73490.0  En avril 1918, le gouvernement britannique d""...
# 22      28784.0  Following Microsoft's announcement last month ...
# 23      62395.0  The national and Islamic factions have announc...
# 24      69265.0  Oxford University's Students' Palestine Societ...
# 25      86776.0  One of the most persistent and constant themes...
# 26      16413.0  For some time now, Microsoft has been building...
# 27      85307.0  Selon Tamim, le r""ve d'un tel Etat ne se r""a...
# 28      17455.0  The Xbox 360 is more than 10 years old, but Mi...
# 29      88957.0  Familiar names such as Palestine native Adrian...
# ...         ...                                                ...
# 26635   97039.0  The 43-year-old teacher grew up in a Palestini...
# 26636   90906.0  Statement by the PLO Executive Committee Membe...
# 26637   29679.0  Softsource has launched its next generation In...
# 26638   66847.0  He pointed out that the collaboration aims to ...
# 26639   31149.0  VMware, Cisco and Microsoft top the list of cu...
# 26640    5771.0  Microsoft OneDrive for Business is now availab...
# 26641   69599.0  Get the hell out of Palestinian towns, village...
# 26642     123.0  Microsoft's insistence on safe guarding inform...
# 26643   27456.0  At long last, Microsoft has bought Xamarin, Th...
# 26644    3854.0  """Hewlett Packard Enterprise and Microsoft sh...
# 26645    4181.0  """As the enterprise market becomes increasing...
# 26646   66008.0  Spangler delivered her lecture, """Witnessing ...
# 26647   23443.0  Cloud accounting firm Xero has teamed up with ...
# 26648  101249.0  As the temperatures warm up and the kids are o...
# 26649   87747.0  Activists from Palestinian President Mahmoud A...
# 26650   91574.0  Stewart O’Nan’s slim but complex novel “City o...
# 26651   62984.0  The UAE have been urged not to waste their cha...
# 26652   83496.0  Katie O’Kelly writes about her time in Palesti...
# 26653   72343.0  “People in your country know what it means to ...
# 26654   64950.0  Dr. Marsha Levine, a retired researcher Univer...
# 26655   87155.0  An operator in Belgium’s federal hotline on th...
# 26656   74017.0  Alex Dunne has been in the West Bank for over ...
# 26657   79781.0  Jewish students at four City University of New...
# 26658  102037.0  The Palestine Liberation Organisation (PLO) ha...
# 26659  100399.0  EVERY TD AND SENATOR in the new Dáil is being ...
# 26660   88044.0  JEDDAH: Saud bin Badi Al-Ramali, a 90-year-old...
# 26661   67119.0  Although international attention has waned reg...
# 26662   15247.0  Microsoft, in a bid to leverage the opportunit...
# 26663   63326.0  The American Anthropological Association has t...
# 26664   89785.0  On Thursday April 7, the Wesleyan Refugee Proj...
#
#                                                Source      Topic  \
# 0                                KXXV News Channel 25  palestine
# 1                                        KLTV 7 Tyler  palestine
# 2                                   Winona Daily News  palestine
# 3                            Mason City Globe Gazette  palestine
# 4                                          Stockhouse  microsoft
# 5                    GlobeNewswire via Yahoo! Finance  microsoft
# 6                   InvestorIdeas.com (press release)  microsoft
# 7                                                The   palestine
# 8                                       Pulse Nigeria  microsoft
# 9                   InvestorIdeas.com (press release)  microsoft
# 10                                          DNA India  palestine
# 11                                      thejournal.ie  microsoft
# 12                             Palestine News Network  palestine
# 13                                          Al-Bawaba  palestine
# 14                                        Phone Arena  microsoft
# 15             Charleston Gazette-Mail (subscription)  microsoft
# 16                                           PC World  microsoft
# 17                                Middle East Monitor  palestine
# 18                                 Bay Area Indymedia  palestine
# 19                           GameSpot via Yahoo! News  microsoft
# 20                                           GameSpot  microsoft
# 21                                          Mediapart  palestine
# 22                                           GameSpot  microsoft
# 23             Ahlul Bayt News Agency (press release)  palestine
# 24                                    Cherwell Online  palestine
# 25                                     Open Democracy  palestine
# 26                                            WinBeta  microsoft
# 27                                            i24news  palestine
# 28                           GameSpot via Yahoo! News  microsoft
# 29                                    Toledo News Now  palestine
# ...                                               ...        ...
# 26635                             malaysiandigest.com  palestine
# 26636                          Palestine News Network  palestine
# 26637                                   Reseller News  microsoft
# 26638                                    Trade Arabia  palestine
# 26639                                   Reseller News  microsoft
# 26640                       Computerworld New Zealand  microsoft
# 26641                              Intifada Palestine  palestine
# 26642                       Computerworld New Zealand  microsoft
# 26643                                           ZDNet  microsoft
# 26644                                   Reseller News  microsoft
# 26645                                   Reseller News  microsoft
# 26646                               The Daily Gazette  palestine
# 26647                                           ZDNet  microsoft
# 26648                                          Fox 59  palestine
# 26649                                   Vancouver Sun  palestine
# 26650                                   Seattle Times  palestine
# 26651                Gulf News via Yahoo Maktoob News  palestine
# 26652       TheJournal.ie via Yahoo UK & Ireland News  palestine
# 26653                                       The Hindu  palestine
# 26654                                   National Post  palestine
# 26655                                     The Forward  palestine
# 26656       TheJournal.ie via Yahoo UK & Ireland News  palestine
# 26657                                   New York Post  palestine
# 26658                                            The   palestine
# 26659                                    An Phoblacht  palestine
# 26660                                       Arab News  palestine
# 26661                                  United Nations  palestine
# 26662  The Financial Express via Yahoo! Finance India  microsoft
# 26663                                       Salon.com  palestine
# 26664                              The Wesleyan Argus  palestine
#
#                PublishDate  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0      2016-05-27 00:05:35          -0.179148         1           0         0
# 1      2016-05-26 16:14:00          -0.121528         0           0         0
# 2      2016-06-17 04:31:48           0.016549         0           0         0
# 3      2016-06-04 01:55:36           0.129046         0           0         0
# 4      2015-11-30 20:20:18           0.057354         1           0         0
# 5      2015-11-30 11:53:00           0.021554         0           0        30
# 6      2016-06-27 14:40:12          -0.119338        -1           0        43
# 7      2016-05-16 06:17:00           0.178221        -1          -1        -1
# 8      2015-12-26 07:10:26          -0.150967         7           1         0
# 9      2016-01-11 17:00:26          -0.117851         0           0         0
# 10     2016-01-18 17:32:00          -0.049176         2           0         0
# 11     2016-03-05 11:18:36           0.023719         0           0         0
# 12     2015-12-11 07:47:45          -0.341000        19           0         0
# 13     2016-03-21 00:00:00          -0.193793        16          10         0
# 14     2016-02-28 18:15:32           0.374228         9          13         1
# 15     2016-05-31 02:40:11          -0.223607         3           0         0
# 16     2015-03-01 07:56:00           0.062552        -1          -1        -1
# 17     2016-02-11 14:17:10          -0.215077        43           0         0
# 18     2016-02-13 14:56:09          -0.052129         2           0         0
# 19     2016-01-25 14:43:00          -0.047328         3           0         1
# 20     2016-01-25 22:44:27          -0.171003       234          18         1
# 21     2016-01-20 14:05:18          -0.076547         4           0         0
# 22     2016-03-03 16:19:34           0.075440        68           9         1
# 23     2015-11-18 00:00:00          -0.093955        -1          -1        -1
# 24     2015-12-11 00:00:00          -0.054554        -1          -1        -1
# 25     2016-03-29 22:15:24           0.102062         3           0         0
# 26     2016-01-13 17:29:26           0.067680         5           5         1
# 27     2016-03-22 06:55:20          -0.072169        76           1         0
# 28     2016-01-16 06:02:00           0.160357         0           0         0
# 29     2016-04-06 15:08:00           0.316912        53           0         0
# ...                    ...                ...       ...         ...       ...
# 26635  2016-05-16 00:00:00          -0.068096         0           0         0
# 26636  2016-04-18 07:55:17          -0.008541        10           0         0
# 26637  2016-03-07 21:00:39           0.110485         1           0        12
# 26638  2015-12-14 14:32:46           0.159901         0           0         0
# 26639  2016-03-13 21:40:41           0.081832         0           0         2
# 26640  2015-11-30 23:40:18           0.148726         0           0         9
# 26641  2015-12-30 18:24:48          -0.141923        85          39         1
# 26642  2015-11-09 18:40:17           0.127578         7           0         7
# 26643  2016-02-26 21:40:34          -0.060417        28          24       174
# 26644  2015-11-22 19:29:17          -0.162902         0           0         8
# 26645  2015-11-23 19:20:17          -0.114909         0           0         3
# 26646  2015-11-15 00:00:00          -0.139754        -1          -1        -1
# 26647  2016-02-10 00:40:28           0.073438        19           7       360
# 26648  2016-06-14 13:12:48           0.027272        31           0         0
# 26649  2016-03-17 11:22:00          -0.050000        -1          -1        -1
# 26650  2016-04-21 11:05:00          -0.231455         0           0         0
# 26651  2015-11-10 22:46:00          -0.254771        -1          -1        -1
# 26652  2016-03-11 07:49:00           0.312500        -1          -1        -1
# 26653  2016-01-13 16:43:00           0.024772         0           0         0
# 26654  2015-12-02 08:17:00          -0.100678        34          10         3
# 26655  2016-03-31 04:09:00          -0.135831        22           2         0
# 26656  2016-01-23 03:32:00           0.102062         0           0         0
# 26657  2016-02-23 23:22:00          -0.142249       868          18         2
# 26658  2016-06-19 11:47:00          -0.004410       135           1         0
# 26659  2016-06-08 02:04:00          -0.120035        38           0         0
# 26660  2016-03-21 13:51:00          -0.096806        -1          -1        -1
# 26661  2015-12-15 08:17:00           0.080850         1          17         0
# 26662  2016-01-09 08:56:00           0.057232         0           0         0
# 26663  2015-11-24 05:16:00          -0.179122       116           0         0
# 26664  2016-04-11 20:16:00          -0.024835         1           0         0
#
# [26665 rows x 11 columns]

# %% [markdown]
# ### Data Visualization

# %%
fb_micro = pd.read_csv('Facebook_Microsoft.csv')
gp_micro = pd.read_csv('GooglePlus_Microsoft.csv')
li_micro = pd.read_csv('LinkedIn_Microsoft.csv')

fb_pal = pd.read_csv('Facebook_Palestine.csv')
gp_pal = pd.read_csv('GooglePlus_Palestine.csv')
li_pal = pd.read_csv('LinkedIn_Palestine.csv')

final = pd.read_csv('News_Final.csv')

# %%
# Cleaning data based on the topics required
temp1 = np.where((final['Topic']=='obama'))[0]   #index of Palestine
temp2 = np.where(final['Topic']=='economy')[0]  #index of microsoft
print(len(temp1)+len(temp2))
final.shape #initial shape  -- final dataframe
# Out:
# 62538
# (93239, 11)

# %%
final.drop(temp1,axis=0,inplace=True)   #Dropping Palestine
final.drop(temp2,axis=0,inplace=True)   #Dropping Microsoft
final.shape #final shape  -- final dataframe
# Out:
# (30701, 11)

# %%
final.dtypes
# Out:
# IDLink               float64
# Title                 object
# Headline              object
# Source                object
# Topic                 object
# PublishDate           object
# SentimentTitle       float64
# SentimentHeadline    float64
# Facebook               int64
# GooglePlus             int64
# LinkedIn               int64
# dtype: object

# %%
#sorting the data according to the publish date
final=final.sort_values(by='PublishDate')
final.head(1)
# Out:
#     IDLink                                              Title  \
# 5  27790.0  Intellitec Solutions to Host 13th Annual Sprin...
#
#                                             Headline Source      Topic  \
# 5  Over 100 attendees expected to see latest vers...  PRWeb  microsoft
#
#            PublishDate  SentimentTitle  SentimentHeadline  Facebook  \
# 5  2015-03-01 00:19:00       -0.075378           0.036773        -1
#
#    GooglePlus  LinkedIn
# 5          -1        -1

# %%
final['PublishDate']=pd.to_datetime(final['PublishDate'])    #converting the data type from category to date format

# %% [markdown]
# #### Removing records that never entered Social Media

# %%
temp1 = set(np.where(final['Facebook']==-1)[0])   #index of Facebook = -1
temp2 = set(np.where(final['LinkedIn']==-1)[0])     #index of LinkedIn = -1
temp3 = set(np.where(final['GooglePlus']==-1)[0])   #index of GooglePlus = -1

# %%
#Replacing the -1 values with nan
final.Facebook.replace(-1,np.nan,inplace=True)
final.LinkedIn.replace(-1,np.nan,inplace=True)
final.GooglePlus.replace(-1,np.nan,inplace=True)

# %%
#droping all the nan values if all 3 social media attributes are having -1 
final.dropna(thresh=9,inplace=True)

# %%
# replacing back the -1 values
final.Facebook.replace(np.nan,-1,inplace=True)
final.LinkedIn.replace(np.nan,-1,inplace=True)
final.GooglePlus.replace(np.nan,-1,inplace=True)

# %%
#Identifying the null columns

final.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline               4
# Source               185
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %%
#Identifying the null indices

l1 = list(final[final['Headline'].isnull()].index)
l2 = list(final[final['Source'].isnull()].index)
s1 = set(l1)
s2 = set(l2)
len(s1.union(s2))
# Out:
# 189

# %%
#Percentage of null indices compared to the overall size

len(s1.union(s2))/final.shape[0]
# Out:
# 0.006747349255649566

# %% [raw]
# We can drop the null values after merging it with the six data files - since, we have to check if the final sentiment score of social media columns in final dataframe.

# %% [markdown]
# #### Categorizing Source

# %%
#Reading the journal excel file and appending to an empty list 
journal = pd.read_excel('ESIMasterJournalList-122018.xlsx',sheet_name='Sheet1')
journal = journal['Full title'] 
k = list()
for i in journal:
    j=str(i).strip()
    j=j.lower()
    k.append(j)

# %%
j=0
l=list()
for i in final['Source']:
    i=str(i)
    i=i.strip()
    i=i.lower()
#Categorizing all the online source from source
    if(i.find('yahoo') >= 0 or i.find('.gov')>0 or i.find('.fr')>=0):
        l.append('Online')
    elif(i.find('.com')>0 or i.find('.co')>=0 or i.find('blog')>=0 or i.find('.ca')>=0 or i.find('.tv')>=0 or (i=='bloomberg')):
        l.append('Online')
#categorizing all the dailies and journals 
    
    elif(i in k):
        l.append('Dailies/Journals')
    
    elif(i.find('today') >= 0 or i.find('times') >= 0 or i.find('daily')>=0 or i.startswith('the')):
        l.append('Dailies/Journals')
        
    elif(i.find('journal')>=0 or i.find('post')>=0 or i.find('magazine')>=0 or i.find('forbes')>=0 or i.find('tass')>=0):
        l.append('Dailies/Journals')
    elif(i.find('nasdaq')>=0 or i.find('reuters')>=0 or i.find('sputnik')>=0 or i.find('mid-day')>=0 or i.find('quartz')>=0):
        l.append('Dailies/Journals')
    elif(i.find('herald')>=0 or i.find('market')>=0 or i.find('business')>=0):
        l.append('Dailies/Journals')
        
#Categorizing all the TV news chaneels
        
    elif(i.find('cnn') >= 0 or i.find('fxstreet')>=0 or i.find('bcc') >= 0 or i.find('cnbc') >= 0 or i.find('news')>=0):
        l.append('Television')
    elif(i=='time' or i.find('live')>0 or i.find('ndtv')>=0 or i.find('abc') >= 0 or i.find('press')>=0 or (i=='msnbc')):
        l.append('Television')
    elif(i.find('cbs')>0):
        l.append('Television')

    else: 
        l.append('Dailies/Journals')
final['S_Source']=l

# %%
#count of news items each category has
final['S_Source'].value_counts()
# Out:
# Dailies/Journals    19516
# Online               5605
# Television           2890
# Name: S_Source, dtype: int64

# %%
# Striping the publish date to find the mont column
final['PublishDate'] = final.PublishDate.astype('str')
final['month'] = final['PublishDate'].str[0:7]
final['month'] = pd.to_datetime(final['month'])
final.head(2)
# Out:
#      IDLink                                              Title  \
# 726   311.0  Microsoft offering £100 discount on original B...
# 729   307.0    Microsoft scales back free online storage plans
#
#                                               Headline  \
# 726  Just ahead of the market rollout of Microsoft'...
# 729  NEW YORK — Microsoft is getting stingy with on...
#
#                                                 Source      Topic  \
# 726  International Business Times via Yahoo UK & Ir...  microsoft
# 729                                      The Columbian  microsoft
#
#              PublishDate  SentimentTitle  SentimentHeadline  Facebook  \
# 726  2015-11-08 05:25:00        0.000000          -0.132812       0.0
# 729  2015-11-08 06:54:00        0.106303          -0.207333       0.0
#
#      GooglePlus  LinkedIn          S_Source      month
# 726         0.0       0.0            Online 2015-11-01
# 729         0.0       0.0  Dailies/Journals 2015-11-01

# %% [markdown]
# #### Creating a master DataFrame

# %%
# Shape of all the 6 files
print(fb_micro.shape)
print(fb_pal.shape)
print(li_micro.shape)
print(li_pal.shape)
print(gp_micro.shape)
print(gp_pal.shape)
# Out:
# (18531, 145)
# (7687, 145)
# (20702, 145)
# (7749, 145)
# (20702, 145)
# (7749, 145)

# %%
# Different categories of titles 
fb_micro['sm_title']='fb_micro'
fb_pal['sm_title']='fb_pal'
li_micro['sm_title']='li_micro'
li_pal['sm_title']='li_pal'
gp_micro['sm_title']='gp_micro'
gp_pal['sm_title']='gp_pal'

# %%
frame = [fb_micro,fb_pal,li_micro,li_pal,gp_micro,gp_pal]  # cancating all the 6 files
result = pd.concat(frame)
result.head()
# Out:
#    IDLink  TS1  TS2  TS3  TS4  TS5  TS6  TS7  TS8  TS9    ...     TS136  \
# 0     101   -1   -1   -1   -1   -1   30   30   30   30    ...       131
# 1     102   -1   -1   -1   -1   -1   -1   -1   -1   -1    ...        57
# 2     103   -1   -1   -1   -1   -1   -1   -1   -1   -1    ...       259
# 3     104   -1   -1   -1   -1   -1   -1   -1   -1   -1    ...        13
# 4     105   -1   -1   -1   -1   -1   -1   -1   -1   -1    ...       314
#
#    TS137  TS138  TS139  TS140  TS141  TS142  TS143  TS144  sm_title
# 0    131    131    131    131    131    131    133    133  fb_micro
# 1     57     57     57     57     57     58     58     58  fb_micro
# 2    260    260    260    260    261    262    262    263  fb_micro
# 3     13     13     13     13     13     13     13     13  fb_micro
# 4    315    315    316    316    316    316    316    316  fb_micro
#
# [5 rows x 146 columns]

# %%
result.shape
# Out:
# (83120, 146)

# %%
result.replace(-1,np.nan,inplace=True)

# %%
result.dropna(thresh=3,inplace=True)

# %%
result.shape
# Out:
# (81677, 146)

# %%
2455/177395
# Out:
# 0.013839172468220638

# %%
result.replace(np.nan,-1,inplace=True)

# %%
#merging the files using the IDLink
data = pd.merge(final,result,on='IDLink')
data.shape
# Out:
# (81686, 158)

# %%
data.isnull().sum()
# Out:
# IDLink                 0
# Title                  0
# Headline              12
# Source               554
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# S_Source               0
# month                  0
# TS1                    0
# TS2                    0
# TS3                    0
# TS4                    0
# TS5                    0
# TS6                    0
# TS7                    0
# TS8                    0
# TS9                    0
# TS10                   0
# TS11                   0
# TS12                   0
# TS13                   0
# TS14                   0
# TS15                   0
# TS16                   0
# TS17                   0
#                     ...
# TS116                  0
# TS117                  0
# TS118                  0
# TS119                  0
# TS120                  0
# TS121                  0
# TS122                  0
# TS123                  0
# TS124                  0
# TS125                  0
# TS126                  0
# TS127                  0
# TS128                  0
# TS129                  0
# TS130                  0
# TS131                  0
# TS132                  0
# TS133                  0
# TS134                  0
# TS135                  0
# TS136                  0
# TS137                  0
# TS138                  0
# TS139                  0
# TS140                  0
# TS141                  0
# TS142                  0
# TS143                  0
# TS144                  0
# sm_title               0
# Length: 158, dtype: int64

# %%
data.dropna(inplace=True)  #Dropping all the null values of headlines and source

# %%
r=pd.concat(frame)

# %%
r[r['TS144']==-1].groupby(['TS144']).sum()
# Out:
#          IDLink   TS1   TS2   TS3   TS4   TS5   TS6   TS7   TS8   TS9  ...    \
# TS144                                                                  ...
# -1     72686399 -1443 -1443 -1443 -1443 -1443 -1443 -1443 -1443 -1443  ...
#
#        TS134  TS135  TS136  TS137  TS138  TS139  TS140  TS141  TS142  TS143
# TS144
# -1     -1443  -1443  -1443  -1443  -1443  -1443  -1443  -1443  -1443  -1443
#
# [1 rows x 144 columns]

# %%
len(r)
# Out:
# 83120

# %%
2455/177395
# Out:
# 0.013839172468220638

# %%
#count of all the news of microsoft and palestine in the final file
final['Topic'].value_counts()
# Out:
# microsoft    20415
# palestine     7596
# Name: Topic, dtype: int64

# %%
#count of news of microsoft and palestine in the data file
data['Topic'].value_counts()
# Out:
# microsoft    58949
# palestine    22171
# Name: Topic, dtype: int64

# %%
#striping of the 3 social media names from sm_title
data['sm'] = data['sm_title'].str[0:2]

# %%
#count plot
sns.countplot('Topic',hue='sm',data=data)
plt.legend(loc=0)
plt.show()

# %% [raw]
# Popularity based on weekday and weekend

# %%
final['weekday']=final['month'].apply(lambda x:x.weekday())

# %%
final['weekday/weekend']=np.where(final['weekday']<=5,'weekday','weekend')

# %%
final.tail()
# Out:
#          IDLink                                              Title  \
# 93229   61849.0  Read Microsoft's Cringeworthy Millennial-Bait ...
# 93233  104799.0        Tournoi de foot solidaire pour la Palestine
# 93236  104793.0  Palestinian Government Uses Foreign Aid To Pay...
# 93237  104794.0  Palestine Youth Orchestra prepares for first U...
# 93238   61870.0  Sausalito businesswoman wins $10000 in Microso...
#
#                                                 Headline          Source  \
# 93229  For any corporate recruiter thinking about add...         Fortune
# 93233  Dans le cadre de la campagne annuelle de solid...      L'Humanité
# 93236  The Palestinian government spends nearly $140 ...    Daily Caller
# 93237  Palestine Youth Orchestra prepares for first U...    Ahram Online
# 93238  Goldstein, the proprietor of the TG Travel Gro...  East Bay Times
#
#            Topic          PublishDate  SentimentTitle  SentimentHeadline  \
# 93229  microsoft  2016-07-07 15:06:11        0.051031           0.178885
# 93233  palestine  2016-07-07 15:20:27       -0.047246          -0.106600
# 93236  palestine  2016-07-07 15:38:26        0.291667          -0.139754
# 93237  palestine  2016-07-07 15:59:22        0.121534           0.092313
# 93238  microsoft  2016-07-07 16:16:11        0.000000           0.054554
#
#        Facebook  GooglePlus  LinkedIn          S_Source      month  weekday  \
# 93229      -1.0         0.0       6.0  Dailies/Journals 2016-07-01        4
# 93233       4.0         0.0       0.0  Dailies/Journals 2016-07-01        4
# 93236       5.0         1.0       0.0  Dailies/Journals 2016-07-01        4
# 93237       0.0         0.0       0.0  Dailies/Journals 2016-07-01        4
# 93238      -1.0         1.0       0.0  Dailies/Journals 2016-07-01        4
#
#       weekday/weekend
# 93229         weekday
# 93233         weekday
# 93236         weekday
# 93237         weekday
# 93238         weekday

# %%
#Count of obama and economy per month
print('\n')
for i in final.Topic.unique():
    plt.plot(final[final['Topic']==i].groupby(['month']).IDLink.count(),label=i)
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
final[final['Topic']=='microsoft'].groupby(['month']).month.value_counts()
# Out:
# month       month
# 2015-11-01  2015-11-01    2056
# 2015-12-01  2015-12-01    2543
# 2016-01-01  2016-01-01    2747
# 2016-02-01  2016-02-01    2321
# 2016-03-01  2016-03-01    2745
# 2016-04-01  2016-04-01    2457
# 2016-05-01  2016-05-01    2543
# 2016-06-01  2016-06-01    2527
# 2016-07-01  2016-07-01     476
# Name: month, dtype: int64

# %%
final[final['Topic']=='palestine'].groupby(['month']).month.value_counts()
# Out:
# month       month
# 2015-11-01  2015-11-01     471
# 2015-12-01  2015-12-01    1074
# 2016-01-01  2016-01-01    1195
# 2016-02-01  2016-02-01    1002
# 2016-03-01  2016-03-01    1078
# 2016-04-01  2016-04-01     882
# 2016-05-01  2016-05-01     845
# 2016-06-01  2016-06-01     864
# 2016-07-01  2016-07-01     185
# Name: month, dtype: int64

# %%
# avarage sentiments of economy and obama
print('Sentiment Title\n')
for i in final.Topic.unique():
    plt.plot(final[final['Topic']==i].groupby(['month']).SentimentTitle.mean(),label=i)
plt.xticks(rotation=60)
plt.title('Sentiment Title')
plt.legend()
plt.show()

print('Sentiment HeadLine\n')
for i in final.Topic.unique():
    plt.plot(final[final['Topic']==i].groupby(['month']).SentimentHeadline.mean(),label=i)
plt.xticks(rotation=60)
plt.title('Sentiment Headline')
plt.legend()
plt.show()
# Out:
# Sentiment Title
# Sentiment HeadLine

# %%
# Plot 1- Average unique topics in facebook for each month

for i in data.Topic.unique():
    plt.plot(data[data['Topic']==i].groupby(['month']).Facebook.mean(),label=i)
plt.xticks(rotation=60)
plt.title('Facebook')
plt.legend()
plt.show()

# Plot 2- Average unique topics in LinkedIn for each month


for i in data.Topic.unique():
    plt.plot(data[data['Topic']==i].groupby(['month']).LinkedIn.mean(),label=i)
plt.xticks(rotation=60)
plt.title('LinkedIn')
plt.legend()
plt.show()

#Plot 3- Average unique topics in GooglePlus for each month

for i in data.Topic.unique():
    plt.plot(data[data['Topic']==i].groupby(['month']).GooglePlus.mean(),label=i)
plt.xticks(rotation=60)
plt.title('Google Plus')
plt.legend()
plt.show()

# %%
facebook = [fb_micro,fb_pal]   #concating all the items according to the social platform
facebook = pd.concat(facebook)

linkedin = [li_micro,li_pal]
linkedin = pd.concat(linkedin)

gplus = [gp_micro,gp_pal]
googleplus = pd.concat(gplus)

# %%
#plot-1 The grap explains the time span the news took to enter social media platform
print('Facebook:\n\n')

columns = [i for i in facebook if i not in ('IDLink','sm_title')]
l1 = list()
l2 = list()
l3 = range(1,145)
for i in columns:
    t_ob=np.mean(fb_micro[i])
    t_ec=np.mean(fb_pal[i])
    l1.append(t_ob/np.mean(fb_micro['TS144']))
    l2.append(t_ec/np.mean(fb_pal['TS144']))
plt.figure(figsize=(15,8))
plt.plot(l3,l1,label='microsoft')
plt.plot(l3,l2,label='palestine')
plt.xlabel('Time Slice')
plt.ylabel('Popularity Score')
plt.title('Popularity Score : Facebook')
plt.legend()
plt.show()

print('LinkedIN:\n\n')

columns = [i for i in linkedin if i not in ('IDLink','sm_title')]
l1 = list()
l2 = list()
l3 = range(1,145)
for i in columns:
    t_ob=np.mean(li_micro[i])
    t_ec=np.mean(li_pal[i])
    l1.append(t_ob/np.mean(li_micro['TS144']))
    l2.append(t_ec/np.mean(li_pal['TS144']))
plt.figure(figsize=(15,8))
plt.plot(l3,l1,label='microsoft')
plt.xlabel('Time Slice')
plt.ylabel('Popularity Score')
plt.plot(l3,l2,label='palestine')
plt.title('Popularity Score : LinkedIn')
plt.legend()
plt.show()

print('Google Plus:\n\n')

columns = [i for i in googleplus if i not in ('IDLink','sm_title')]
l1 = list()
l2 = list()
l3 = range(1,145)
for i in columns:
    t_ob=np.mean(gp_micro[i])
    t_ec=np.mean(gp_pal[i])
    l1.append(t_ob/np.mean(gp_micro['TS144']))
    l2.append(t_ec/np.mean(gp_pal['TS144']))
plt.figure(figsize=(15,8))
plt.plot(l3,l1,label='microsoft')
plt.plot(l3,l2,label='palestine')
plt.xlabel('Time Slice')
plt.ylabel('Popularity Score')
plt.title('Popularity Score : Google Plus')
plt.legend()
plt.show()
# Out:
# Facebook:
# LinkedIN:
# Google Plus:

# %% [markdown]
# #### High to Low SentimentTitle score based on Source

# %%
df[['Source','SentimentTitle']].groupby('Source').agg('median').sort_values(by='SentimentTitle',ascending=False).head()
# Out:
#                             SentimentTitle
# Source
# Yahoo Tech via Yahoo! News        0.714610
# Focus News                        0.500000
# ChinaTopix                        0.474342
# Mensquare                         0.395292
# 4k                                0.376889

# %%
df[['Topic','SentimentTitle','SentimentHeadline']].groupby('Topic').agg('mean').sort_values(by='SentimentTitle',ascending=False)
# Out:
#            SentimentTitle  SentimentHeadline
# Topic
# microsoft        0.002363          -0.014745
# palestine       -0.020081          -0.044500

# %% [markdown]
# #### Convert Published Date to Datetime

# %%
df['Date'] = pd.to_datetime(df['PublishDate'])

# %%
df['Date'].min(),df['Date'].max()
# Out:
# (Timestamp('2015-03-01 00:19:00'), Timestamp('2016-07-07 16:16:11'))

# %%
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day
df['year'] = df['Date'].dt.year
df['month_name'] = df['Date'].dt.strftime('%b')
df['weekday'] = df['Date'].dt.strftime('%A')

# %% [markdown]
# #### Monday is having the Highest number of News Published

# %%
df.weekday.value_counts()
# Out:
# Monday       5671
# Tuesday      5638
# Wednesday    5421
# Thursday     5126
# Friday       4287
# Sunday       2320
# Saturday     2234
# Name: weekday, dtype: int64

# %% [markdown]
# #### March is having the Highest number of News Published, while it is coming 2 times in 2015 and 2016.

# %%
df.month_name.value_counts()
# Out:
# Mar    4282
# Jan    4210
# Dec    3857
# May    3678
# Jun    3639
# Apr    3597
# Feb    3510
# Nov    3021
# Jul     680
# Oct     219
# Sep       3
# Aug       1
# Name: month_name, dtype: int64

# %% [markdown]
# #### Making of wordCloud from Title

# %%
df_microsoft = df[df['Topic'] == 'microsoft']
df_palestine = df[df['Topic'] == 'palestine']

#Corpus

docs = df_microsoft.Title.str.lower().str.replace('[^a-z\' ]','')
stopwords = nltk.corpus.stopwords.words('English')
stopwords.extend(['microsoft','new'])

stemmer = nltk.stem.PorterStemmer()
def clean_sen(text):
    text=str(text)
    ws = text.split(' ')
    ws = [w.strip() for w in ws]
    ws_clean = [w for w in ws if w not in stopwords]
    return ' '.join(ws_clean)

docs_clean = docs.apply(clean_sen)

#Merging all paragraphs as a single string
text = ' '.join(para for para in docs_clean)

#Creating the word cloud
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='white').generate(text)
plt.imshow(wc)

# %%
df_microsoft = df[df['Topic'] == 'microsoft']
df_palestine = df[df['Topic'] == 'palestine']

#Corpus

docs = df_palestine.Title.str.lower().str.replace('[^a-z\' ]','')
stopwords = nltk.corpus.stopwords.words('English')
stopwords.extend(['palestine','palestinian'])

stemmer = nltk.stem.PorterStemmer()
def clean_sen(text):
    text=str(text)
    ws = text.split(' ')
    ws = [w.strip() for w in ws]
    ws_clean = [w for w in ws if w not in stopwords]
    return ' '.join(ws_clean)

docs_clean = docs.apply(clean_sen)

#Merging all paragraphs as a single string
text = ' '.join(para for para in docs_clean)

#Creating the word cloud
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='white').generate(text)
plt.imshow(wc)

# %% [markdown]
# #### Making Wordcloud from Headline

# %%
df_microsoft = df[df['Topic'] == 'microsoft']
df_palestine = df[df['Topic'] == 'palestine']

#Corpus

docs = df_microsoft.Headline.str.lower().str.replace('[^a-z\' ]','')
stopwords = nltk.corpus.stopwords.words('English')
stopwords.extend(['microsoft','new'])

stemmer = nltk.stem.PorterStemmer()
def clean_sen(text):
    text=str(text)
    ws = text.split(' ')
    ws = [w.strip() for w in ws]
    ws_clean = [w for w in ws if w not in stopwords]
    return ' '.join(ws_clean)

docs_clean = docs.apply(clean_sen)

#Merging all paragraphs as a single string
text = ' '.join(para for para in docs_clean)

#Creating the word cloud
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='white').generate(text)
plt.imshow(wc)

# %%
df_microsoft = df[df['Topic'] == 'microsoft']
df_palestine = df[df['Topic'] == 'palestine']

#Corpus

docs = df_palestine.Headline.str.lower().str.replace('[^a-z\' ]','')
stopwords = nltk.corpus.stopwords.words('English')
stopwords.extend(['microsoft','new'])

stemmer = nltk.stem.PorterStemmer()
def clean_sen(text):
    text=str(text)
    ws = text.split(' ')
    ws = [w.strip() for w in ws]
    ws_clean = [w for w in ws if w not in stopwords]
    return ' '.join(ws_clean)

docs_clean = docs.apply(clean_sen)

#Merging all paragraphs as a single string
text = ' '.join(para for para in docs_clean)

#Creating the word cloud
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='white').generate(text)
plt.imshow(wc)

# %% [markdown]
# #### Topic Modelling for Microsoft

# %%
docs_title = df['Title'].fillna('').str.lower().str.replace('[^a-z ]','')
docs_headline = df['Headline'].fillna('').str.lower().str.replace('[^a-z ]','')

# %%
stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend([])

docs_title_clean = []
for doc in docs_title:
    words = doc.split(' ')
    wc = [stemmer.stem(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_title_clean.append(wc)

# %%
stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend([])

docs_headline_clean = []
for doc in docs_headline:
    words = doc.split(' ')
    wc = [stemmer.stem(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_headline_clean.append(wc)

# %%
import gensim

dictionary_t = gensim.corpora.Dictionary(docs_title_clean)
dictionary_hl = gensim.corpora.Dictionary(docs_headline_clean)

# %%
docs_bow_title = []
for doc in docs_title_clean:
    bow = dictionary_t.doc2bow(doc)
    docs_bow_title.append(bow)

docs_bow_headline = []
for doc in docs_headline_clean:
    bow = dictionary_t.doc2bow(doc)
    docs_bow_headline.append(bow)

# %%
c_scores = []
for i in range(4,20):
    lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_t,num_topics=i,random_state=100)
    coher_model = CoherenceModel(lda_model,corpus=docs_bow_title,coherence='u_mass')
    score = coher_model.get_coherence()
    c_scores.append(score)

# %%
l1=list(range(4,20))
d=dict()
j=0
for i in l1:
    d[i]=c_scores[j]
    j=j+1
sns.lineplot(l1,c_scores)

# %%
lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_t,num_topics=5,random_state=100)

# %%
lda_model.get_document_topics(docs_bow_title[0])
# Out:
# [(0, 0.018730983),
#  (1, 0.30865327),
#  (2, 0.018885551),
#  (3, 0.018912032),
#  (4, 0.63481814)]

# %%
topics_df = pd.DataFrame(lda_model.get_document_topics(docs_bow_title[1]),columns=['Topic','Probablity'])
topics_df.sort_values(by='Probablity').iloc[:]['Topic']
# Out:
# 2    2
# 1    1
# 0    0
# 4    4
# 3    3
# Name: Topic, dtype: int64

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.082*"microsoft" + 0.073*"" + 0.026*"xbox" + 0.021*"palestin" + 0.016*"one" + 0.010*"game" + 0.007*"window" + 0.007*"palestinian" + 0.006*"israel" + 0.005*"appl"'),
#  (1,
#   '0.106*"microsoft" + 0.071*"" + 0.015*"new" + 0.009*"palestin" + 0.008*"window" + 0.007*"palestinian" + 0.006*"azur" + 0.005*"hololen" + 0.005*"cloud" + 0.005*"develop"'),
#  (2,
#   '0.090*"microsoft" + 0.030*"" + 0.029*"palestin" + 0.014*"surfac" + 0.011*"new" + 0.007*"get" + 0.006*"palestinian" + 0.006*"app" + 0.005*"xbox" + 0.005*"book"'),
#  (3,
#   '0.130*"" + 0.105*"microsoft" + 0.029*"window" + 0.011*"new" + 0.009*"updat" + 0.009*"app" + 0.008*"palestin" + 0.008*"releas" + 0.007*"upgrad" + 0.007*"offic"'),
#  (4,
#   '0.051*"microsoft" + 0.043*"" + 0.037*"palestin" + 0.023*"israel" + 0.023*"palestinian" + 0.008*"isra" + 0.008*"cloud" + 0.006*"anywher" + 0.006*"secur" + 0.005*"bank"')]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aujas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
temp = df[df['Topic']=='microsoft']

docs_title = temp['Title'].fillna('').str.lower().str.replace('[^a-z ]','')
docs_headline = temp['Headline'].fillna('').str.lower().str.replace('[^a-z ]','')

stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend(['microsoft'])

docs_title_clean = []
for doc in docs_title:
    words = doc.split(' ')
    wc = [lemmatizer.lemmatize(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_title_clean.append(wc)

# %%
stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend(['microsoft'])

docs_headline_clean = []
for doc in docs_headline:
    words = doc.split(' ')
    wc = [lemmatizer.lemmatize(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_headline_clean.append(wc)

# %%
dictionary_t = gensim.corpora.Dictionary(docs_title_clean)
dictionary_hl = gensim.corpora.Dictionary(docs_headline_clean)

docs_bow_title = []
for doc in docs_title_clean:
    bow = dictionary_t.doc2bow(doc)
    docs_bow_title.append(bow)

docs_bow_headline = []
for doc in docs_headline_clean:
    bow = dictionary_t.doc2bow(doc)
    docs_bow_headline.append(bow)

# %%
c_scores = []
for i in range(1,10 ):
    lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_t,num_topics=i,random_state=100)
    coher_model = CoherenceModel(lda_model,corpus=docs_bow_title,coherence='u_mass')
    score = coher_model.get_coherence()
    c_scores.append(score)

# %%
l1=list(range(1,10))
d=dict()
j=0
for i in l1:
    d[i]=c_scores[j]
    j=j+1
sns.lineplot(l1,c_scores)

# %%
lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_t,num_topics=2,random_state=100)

# %%
lda_model.get_document_topics(docs_bow_title[0])
# Out:
# [(0, 0.17826457), (1, 0.8217354)]

# %%
topics_df = pd.DataFrame(lda_model.get_document_topics(docs_bow_title[1]),columns=['Topic','Probablity'])
topics_df.sort_values(by='Probablity').iloc[:]['Topic']
# Out:
# 1    1
# 0    0
# Name: Topic, dtype: int64

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.110*"" + 0.023*"window" + 0.020*"microsofts" + 0.013*"surface" + 0.010*"new" + 0.007*"cloud" + 0.006*"google" + 0.006*"pro" + 0.005*"office" + 0.005*"update"'),
#  (1,
#   '0.065*"" + 0.019*"microsofts" + 0.017*"xbox" + 0.012*"window" + 0.011*"new" + 0.010*"one" + 0.006*"azure" + 0.006*"update" + 0.006*"release" + 0.005*"apple"')]

# %% [markdown]
# #### Topic Modelling for Palestine

# %%
temp_pales = df[df['Topic']=='palestine']

docs_title = temp_pales['Title'].fillna('').str.lower().str.replace('[^a-z ]','')
docs_headline = temp_pales['Headline'].fillna('').str.lower().str.replace('[^a-z ]','')

stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend(['palestine'])

docs_title_clean = []
for doc in docs_title:
    words = doc.split(' ')
    wc = [lemmatizer.lemmatize(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_title_clean.append(wc)

# %%
stopwords = nltk.corpus.stopwords.words('English')
stemmer = nltk.stem.PorterStemmer()
stopwords.extend(['palestine'])

docs_headline_clean = []
for doc in docs_headline:
    words = doc.split(' ')
    wc = [lemmatizer.lemmatize(word) for word in words if word not in stopwords]
    wc = [word for word in wc if word not in stopwords]
    docs_headline_clean.append(wc)

# %%
dictionary_e = gensim.corpora.Dictionary(docs_title_clean)
dictionary_eco = gensim.corpora.Dictionary(docs_headline_clean)

docs_bow_title = []
for doc in docs_title_clean:
    bow = dictionary_e.doc2bow(doc)
    docs_bow_title.append(bow)

docs_bow_headline = []
for doc in docs_headline_clean:
    bow = dictionary_e.doc2bow(doc)
    docs_bow_headline.append(bow)

# %%
c_scores = []
for i in range(1,10 ):
    lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_e,num_topics=i,random_state=100)
    coher_model = CoherenceModel(lda_model,corpus=docs_bow_title,coherence='u_mass')
    score = coher_model.get_coherence()
    c_scores.append(score)

# %%
l1=list(range(1,10))
d=dict()
j=0
for i in l1:
    d[i]=c_scores[j]
    j=j+1
sns.lineplot(l1,c_scores)

# %%
lda_model = LdaMulticore(docs_bow_title,id2word=dictionary_e,num_topics=5,random_state=100)

# %%
lda_model.get_document_topics(docs_bow_title[0])
# Out:
# [(0, 0.040203884),
#  (1, 0.041818324),
#  (2, 0.83747315),
#  (3, 0.040333916),
#  (4, 0.040170692)]

# %%
topics_df = pd.DataFrame(lda_model.get_document_topics(docs_bow_title[1]),columns=['Topic','Probablity'])
topics_df.sort_values(by='Probablity').iloc[:]
# Out:
#    Topic  Probablity
# 4      4    0.029073
# 3      3    0.029157
# 1      1    0.029365
# 0      0    0.420254
# 2      2    0.492150

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.019*"" + 0.013*"israel" + 0.012*"israelpalestine" + 0.008*"palestinian" + 0.007*"peace" + 0.007*"new" + 0.007*"right" + 0.007*"un" + 0.005*"report" + 0.005*"say"'),
#  (1,
#   '0.074*"" + 0.029*"israel" + 0.026*"palestinian" + 0.009*"israelpalestine" + 0.007*"israeli" + 0.006*"conflict" + 0.005*"peace" + 0.005*"day" + 0.004*"un" + 0.004*"talk"'),
#  (2,
#   '0.105*"" + 0.023*"palestinian" + 0.009*"israel" + 0.008*"israeli" + 0.007*"new" + 0.006*"call" + 0.006*"support" + 0.006*"state" + 0.006*"peace" + 0.005*"week"'),
#  (3,
#   '0.048*"" + 0.042*"palestinian" + 0.029*"israel" + 0.011*"israeli" + 0.006*"gaza" + 0.005*"un" + 0.005*"visit" + 0.004*"bank" + 0.004*"arab" + 0.004*"west"'),
#  (4,
#   '0.043*"palestinian" + 0.026*"" + 0.013*"israeli" + 0.009*"texas" + 0.008*"east" + 0.005*"woman" + 0.005*"u" + 0.005*"flooding" + 0.005*"student" + 0.004*"killed"')]

# %% [markdown]
# ### Frequently occuring words in Headline and Title

# %%
df.Headline = df.Headline.apply(str)

# %%
docs = df['Headline'].str.lower().str.replace('[^a-z@# ]','')
stopwords = nltk.corpus.stopwords.words('english')
#stopwords.extend(['amp','rt'])
stemmer = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [stemmer.stem(w) for w in words if w not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_sentence)
docs_clean.head()
# Out:
# 5      attende expect see latest version microsoft d...
# 6     ramallah februari   wafa  palestin liber organ...
# 8     hancock counti man lost barn earli monday morn...
# 9     new delhi feb  technolog giant microsoft targe...
# 10    microsoft may burn one bridg still build diffe...
# Name: Headline, dtype: object

# %%
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer()

# %%
ndf1=df[df['Topic']=='microsoft']
docs = ndf1['Headline'].str.lower().str.replace('[^a-z@# ]','')
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(['amp','rt','microsoft','new','today','busi','use','said','year','one','week','microsofts'])
#stemmer = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [lemmatizer.lemmatize(w) for w in words if w not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_sentence)
docs_clean.head()
# Out:
# 5      attendee expected see latest version dynamic ...
# 9     delhi feb  technology giant targeted rival app...
# 10    may burned bridge still building different per...
# 11    platform battle back mwc analysis two parallel...
# 14    ar headset made available developer along thre...
# Name: Headline, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=4, ngram_range=(1,1)) 
# min frequency for a term to appear, ngram is for specifing uni,bigram, inside brackets of ngram range the value is unigram, bigram, tri etc
vectorizer.fit(docs_clean)
dtm=vectorizer.transform(docs_clean)

# %%
nrows = dtm.shape[0]
ncols = dtm.shape[1]
total_values = nrows * ncols
sparsity = (total_values - dtm.size)/total_values*100
sparsity
# Out:
# 99.81330420217844

# %%
df_dtm= pd.DataFrame(dtm.toarray(),columns=vectorizer.get_feature_names())

# %% [markdown]
# #### Frequently occuring words in Headline - Microsoft

# %%
# %matplotlib inline
df_dtm.sum().sort_values(ascending=False).head(20).plot.bar(figsize=(12,6))
plt.show()

# %%
ndf2=df[df['Topic']=='microsoft']
docs =ndf2['Title'].str.lower().str.replace('[^a-z@# ]','')
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(['amp','rt','microsoft','new','today','busi','use','said','year','one','week','microsofts'])
#stemmer = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [lemmatizer.lemmatize(w) for w in words if w not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_sentence)
docs_clean.head()


from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=4, ngram_range=(1,1)) 
# min frequency for a term to appear, ngram is for specifing uni,bigram, inside brackets of ngram range the value is unigram, bigram, tri etc
vectorizer.fit(docs_clean)
dtm=vectorizer.transform(docs_clean)


nrows = dtm.shape[0]
ncols = dtm.shape[1]
total_values = nrows * ncols
sparsity = (total_values - dtm.size)/total_values*100
sparsity

df_dtm= pd.DataFrame(dtm.toarray(),columns=vectorizer.get_feature_names())

# %% [markdown]
# #### Frequently occuring words in Title - Microsoft

# %%
# %matplotlib inline
df_dtm.sum().sort_values(ascending=False).head(20).plot.bar(figsize=(12,6))

# %%
ndf2=df[df['Topic']=='palestine']
docs =ndf2['Headline'].str.lower().str.replace('[^a-z@# ]','')
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(['amp','rt','palestine','palestinian','isra','intern','one','said','israeli','new','year','de','two','first'])
stemmer = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [lemmatizer.lemmatize(w) for w in words if w not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_sentence)
docs_clean.head()
# Out:
# 6      ramallah february   wafa  liberation organizat...
# 8      hancock county man lost barn early monday morn...
# 56     ramallah february   wafa  government japan con...
# 111    ramallah february   wafa  government japan con...
# 140    forced eviction farmer land jordan valley hebr...
# Name: Headline, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=4, ngram_range=(1,1)) 
# min frequency for a term to appear, ngram is for specifing uni,bigram, inside brackets of ngram range the value is unigram, bigram, tri etc
vectorizer.fit(docs_clean)
dtm=vectorizer.transform(docs_clean)

# %%
nrows = dtm.shape[0]
ncols = dtm.shape[1]
total_values = nrows * ncols
sparsity = (total_values - dtm.size)/total_values*100
sparsity
# Out:
# 99.74080954449205

# %%
df_dtm= pd.DataFrame(dtm.toarray(),columns=vectorizer.get_feature_names())

# %% [markdown]
# #### Frequently occuring words in Headline - Palestine

# %%
# %matplotlib inline
df_dtm.sum().sort_values(ascending=False).head(20).plot.bar(figsize=(12,6))

# %% [markdown]
# #### Frequently occuring words in Title - Palestine

# %%
ndf2=df[df['Topic']=='palestine']
docs =ndf2['Title'].str.lower().str.replace('[^a-z@# ]','')
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(['amp','rt','palestine','palestinian','isra','intern','one','said','israeli','new','year','de','two','first'])
#stemmer = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [lemmatizer.lemmatize(w) for w in words if w not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_sentence)
docs_clean.head()


from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=4, ngram_range=(1,1)) 
# min frequency for a term to appear, ngram is for specifing uni,bigram, inside brackets of ngram range the value is unigram, bigram, tri etc
vectorizer.fit(docs_clean)
dtm=vectorizer.transform(docs_clean)


nrows = dtm.shape[0]
ncols = dtm.shape[1]
total_values = nrows * ncols
sparsity = (total_values - dtm.size)/total_values*100
sparsity

df_dtm= pd.DataFrame(dtm.toarray(),columns=vectorizer.get_feature_names())

# %%
# %matplotlib inline
df_dtm.sum().sort_values(ascending=False).head(20).plot.bar(figsize=(12,6))

# %%
wdf=pd.DataFrame(df_dtm.sum().sort_values(ascending=False).head(20).reset_index())
wdf.columns=['Words','Count']
wdf
# Out:
#               Words  Count
# 0            israel   1081
# 1   israelpalestine    284
# 2                un    273
# 3             peace    265
# 4       palestinian    251
# 5             state    239
# 6              east    218
# 7               say    197
# 8         palestine    191
# 9           support    190
# 10             call    187
# 11             gaza    172
# 12         conflict    164
# 13             bank    163
# 14             talk    155
# 15          student    151
# 16            visit    148
# 17            world    142
# 18             west    142
# 19            texas    141

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=wdf.Count,y=wdf.Words)
plt.show()

# %% [markdown]
# # Topic Modelling for Palestine

# %%
import gensim
import nltk

# %%
data=df[df['Topic']=='palestine']

# %%
docs=data['Title'].fillna('').str.lower()
docs=docs.str.replace('[^a-z ]','')
docs.head()
# Out:
# 6                                           monday  feb
# 8      fire claims more than yearold barn in hancock ...
# 56                                          monday  feb
# 111                                        tuesday  mar
# 140    the british must formally  and swiftly  recogn...
# Name: Title, dtype: object

# %%
stopwords=nltk.corpus.stopwords.words('english')
stopwords.extend(['use','','will','one','good'])
stemmer=nltk.stem.PorterStemmer()

docs_clean=[]
for doc in docs:
    words=doc.split(' ')
    words_clean= [stemmer.stem(word) for word in words if word not in stopwords]
    words_clean=[word for word in words_clean if word not in stopwords]
    docs_clean.append(words_clean)

# %%
dictionary = gensim.corpora.Dictionary(docs_clean) # to get the id for every single word

# %%
# bag of words
docs_bow=[]
for doc in docs_clean:
    bow=dictionary.doc2bow(doc)
    docs_bow.append(bow)

# %%
lda_model=gensim.models.LdaMulticore(docs_bow,id2word=dictionary,num_topics=4,random_state=100)

# %% [markdown]
# # Document to topic Relationship

# %%
lda_model.get_document_topics(docs_bow[1])
# Out:
# [(0, 0.89032835), (1, 0.03616782), (2, 0.036793802), (3, 0.036709998)]

# %%
new_df=pd.DataFrame(lda_model.get_document_topics(docs_bow[1]),columns=['topics','probs'])
new_df.sort_values(by='probs').iloc[-1]['topics']
# Out:
# 0.0

# %%
topics=[]
for doc in docs_bow:
    new_df=pd.DataFrame(lda_model.get_document_topics(doc),columns=['topics','probs'])
    topic=new_df.sort_values(by='probs').iloc[-1]['topics']
    topics.append(topic)
#data['topics']=topics

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.094*"palestin" + 0.014*"palestinian" + 0.007*"israel" + 0.006*"week" + 0.006*"support" + 0.005*"polic" + 0.005*"gaza" + 0.005*"peac" + 0.005*"call" + 0.005*"kill"'),
#  (1,
#   '0.042*"palestinian" + 0.037*"palestin" + 0.013*"isra" + 0.013*"israel" + 0.009*"flood" + 0.008*"israelpalestin" + 0.007*"texa" + 0.006*"new" + 0.006*"kill" + 0.005*"peac"'),
#  (2,
#   '0.069*"palestin" + 0.043*"palestinian" + 0.031*"israel" + 0.012*"isra" + 0.006*"un" + 0.006*"visit" + 0.005*"bank" + 0.005*"east" + 0.005*"kill" + 0.004*"new"'),
#  (3,
#   '0.066*"palestin" + 0.016*"israel" + 0.012*"palestinian" + 0.012*"state" + 0.008*"flood" + 0.006*"new" + 0.006*"israelpalestin" + 0.006*"today" + 0.005*"peac" + 0.005*"us"')]

# %%
# coherence
from gensim.models.coherencemodel import CoherenceModel

# %%
c_scores=[]
for i in range(4,20):
    lda_model=gensim.models.LdaMulticore(docs_bow,id2word=dictionary,num_topics=i,random_state=100,iterations=300)
    coher_model=CoherenceModel(lda_model,corpus=docs_bow,coherence='u_mass')
    score=coher_model.get_coherence()
    c_scores.append(score)

# %%
plt.plot(c_scores)
plt.show()

# %% [markdown]
# # Topic Modelling for Microsoft

# %%
data=df[df['Topic']=='microsoft']

# %%
docs=data['Title'].fillna('').str.lower()
docs=docs.str.replace('[^a-z ]','')
docs.head()
# Out:
# 5     intellitec solutions to host th annual spring ...
# 9              microsofts new windows  ad targets apple
# 10    microsoft project centennial seen with univers...
# 11    microsoft sneaks onto android while android sn...
# 14     hololens dev edition costs  with new conker game
# Name: Title, dtype: object

# %%
stopwords=nltk.corpus.stopwords.words('english')
stopwords.extend(['use','','will','one','good'])
stemmer=nltk.stem.PorterStemmer()

docs_clean=[]
for doc in docs:
    words=doc.split(' ')
    words_clean= [stemmer.stem(word) for word in words if word not in stopwords]
    words_clean=[word for word in words_clean if word not in stopwords]
    docs_clean.append(words_clean)

# %%
dictionary = gensim.corpora.Dictionary(docs_clean) # to get the id for every single word

# %%
# bag of words
docs_bow=[]
for doc in docs_clean:
    bow=dictionary.doc2bow(doc)
    docs_bow.append(bow)

# %%
lda_model=gensim.models.LdaMulticore(docs_bow,id2word=dictionary,num_topics=4,random_state=100)

# %%
new_df=pd.DataFrame(lda_model.get_document_topics(docs_bow[1]),columns=['topics','probs'])
new_df.sort_values(by='probs').iloc[-1]['topics']
# Out:
# 3.0

# %%
topics=[]
for doc in docs_bow:
    new_df=pd.DataFrame(lda_model.get_document_topics(doc),columns=['topics','probs'])
    topic=new_df.sort_values(by='probs').iloc[-1]['topics']
    topics.append(topic)
#data['topics']=topics

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.139*"microsoft" + 0.030*"window" + 0.019*"new" + 0.012*"app" + 0.012*"updat" + 0.008*"mobil" + 0.008*"build" + 0.008*"offic" + 0.008*"lumia" + 0.007*"cloud"'),
#  (1,
#   '0.137*"microsoft" + 0.024*"surfac" + 0.012*"pro" + 0.009*"window" + 0.007*"hololen" + 0.006*"appl" + 0.006*"app" + 0.006*"launch" + 0.005*"power" + 0.005*"secur"'),
#  (2,
#   '0.138*"microsoft" + 0.019*"xbox" + 0.014*"window" + 0.011*"linkedin" + 0.009*"cloud" + 0.008*"game" + 0.007*"new" + 0.006*"make" + 0.005*"buy" + 0.005*"band"'),
#  (3,
#   '0.108*"microsoft" + 0.016*"window" + 0.012*"offic" + 0.010*"new" + 0.009*"googl" + 0.008*"appl" + 0.007*"user" + 0.006*"updat" + 0.006*"busi" + 0.005*"us"')]

# %%
# coherence
from gensim.models.coherencemodel import CoherenceModel

# %%
c_scores=[]
for i in range(4,20):
    lda_model=gensim.models.LdaMulticore(docs_bow,id2word=dictionary,num_topics=i,random_state=100,iterations=300)
    coher_model=CoherenceModel(lda_model,corpus=docs_bow,coherence='u_mass')
    score=coher_model.get_coherence()
    c_scores.append(score)

# %%
plt.plot(c_scores)
plt.show()
